# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
import matplotlib.pyplot as plt
import os

# %%
# ✅ Load segmented data
X = np.load("C:/Users/arfao/Desktop/stage_2025/processed_multiclass_filtered500/X_segments.npy")
y = np.load("C:/Users/arfao/Desktop/stage_2025/processed_multiclass_filtered500/y_labels.npy")
print(f"Original class distribution: {Counter(y)}")
# Out:
# Original class distribution: Counter({0: 784535, 1: 4467, 5: 2466, 2: 1093})

# %%
# ✅ Flatten + scale
X_flat = X.reshape((X.shape[0], -1))
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat)

# %%
# ✅ Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, stratify=y, random_state=42)

# %%
# ✅ SMOTE + undersample
target_count = 70000
print(f"Original train distribution: {Counter(y_train)}")

minority_classes = [cls for cls in Counter(y_train) if cls != 0]
smote_strategy = {cls: target_count for cls in minority_classes}

sm = SMOTE(random_state=42, sampling_strategy=smote_strategy)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

rus = RandomUnderSampler(
    sampling_strategy={0: target_count, **{cls: target_count for cls in np.unique(y_train_res) if cls != 0}},
    random_state=42
)
X_train_bal, y_train_bal = rus.fit_resample(X_train_res, y_train_res)
print(f"Balanced train: {Counter(y_train_bal)}")
# Out:
# Original train distribution: Counter({0: 627627, 1: 3574, 5: 1973, 2: 874})
# Balanced train: Counter({0: 70000, 1: 70000, 2: 70000, 5: 70000})

# %%
# ✅ Remap labels
label_map = {0: 0, 1: 1, 2: 2, 5: 3}
class_names = ["Fusion beat", "Normal beat", "Supraventricular ectopic beat", "Ventricular ectopic beat"]

y_train_bal = np.array([label_map[label] for label in y_train_bal])
y_test_remap = np.array([label_map[label] for label in y_test])

# %%
# ✅ Reshape for CNN
time_steps = X.shape[1]
X_train_cnn = X_train_bal.reshape((-1, 1, time_steps)).astype(np.float32)
X_test_cnn = X_test.reshape((-1, 1, time_steps)).astype(np.float32)

# %%
# ✅ Tensors + datasets
X_train_tensor = torch.tensor(X_train_cnn)
y_train_tensor = torch.tensor(y_train_bal, dtype=torch.long)
X_test_tensor = torch.tensor(X_test_cnn)
y_test_tensor = torch.tensor(y_test_remap, dtype=torch.long)

train_ds_full = TensorDataset(X_train_tensor, y_train_tensor)
test_ds = TensorDataset(X_test_tensor, y_test_tensor)

val_size = int(0.2 * len(train_ds_full))
train_size = len(train_ds_full) - val_size
train_ds, val_ds = random_split(train_ds_full, [train_size, val_size])

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=32)
test_loader = DataLoader(test_ds, batch_size=32)

# %%
# ✅ Model
class ECG_CNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv1d(1, 16, kernel_size=7, padding=3)
        self.pool1 = nn.MaxPool1d(2)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=5, padding=2)
        self.pool2 = nn.MaxPool1d(2)
        self.conv3 = nn.Conv1d(32, 64, kernel_size=3, padding=1)
        self.pool3 = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(64, num_classes)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = self.pool1(x)
        x = torch.relu(self.conv2(x))
        x = self.pool2(x)
        x = torch.relu(self.conv3(x))
        x = self.pool3(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

model = ECG_CNN(len(class_names))
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# ✅ Training loop
num_epochs = 50
history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}

for epoch in range(num_epochs):
    model.train()
    train_loss, correct, total = 0, 0, 0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == y_batch).sum().item()
        total += y_batch.size(0)
    avg_train_loss = train_loss / len(train_loader)
    train_acc = correct / total

    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            val_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            val_correct += (preds == y_batch).sum().item()
            val_total += y_batch.size(0)
    avg_val_loss = val_loss / len(val_loader)
    val_acc = val_correct / val_total

    history['train_loss'].append(avg_train_loss)
    history['val_loss'].append(avg_val_loss)
    history['train_acc'].append(train_acc)
    history['val_acc'].append(val_acc)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f} | Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")
# Out:
# Epoch 1/50 | Train Loss: 0.7780 | Val Loss: 0.6285 | Train Acc: 0.7027 | Val Acc: 0.7678
# Epoch 2/50 | Train Loss: 0.5350 | Val Loss: 0.4534 | Train Acc: 0.8031 | Val Acc: 0.8331
# Epoch 3/50 | Train Loss: 0.4128 | Val Loss: 0.3563 | Train Acc: 0.8510 | Val Acc: 0.8753
# Epoch 4/50 | Train Loss: 0.3362 | Val Loss: 0.2932 | Train Acc: 0.8809 | Val Acc: 0.8955
# Epoch 5/50 | Train Loss: 0.2858 | Val Loss: 0.2494 | Train Acc: 0.8992 | Val Acc: 0.9147
# Epoch 6/50 | Train Loss: 0.2499 | Val Loss: 0.2381 | Train Acc: 0.9114 | Val Acc: 0.9170
# Epoch 7/50 | Train Loss: 0.2253 | Val Loss: 0.2150 | Train Acc: 0.9214 | Val Acc: 0.9252
# Epoch 8/50 | Train Loss: 0.2050 | Val Loss: 0.1932 | Train Acc: 0.9292 | Val Acc: 0.9337
# Epoch 9/50 | Train Loss: 0.1893 | Val Loss: 0.1803 | Train Acc: 0.9346 | Val Acc: 0.9373
# Epoch 10/50 | Train Loss: 0.1748 | Val Loss: 0.2115 | Train Acc: 0.9398 | Val Acc: 0.9247
# Epoch 11/50 | Train Loss: 0.1650 | Val Loss: 0.1637 | Train Acc: 0.9436 | Val Acc: 0.9412
# Epoch 12/50 | Train Loss: 0.1548 | Val Loss: 0.1639 | Train Acc: 0.9473 | Val Acc: 0.9450
# Epoch 13/50 | Train Loss: 0.1450 | Val Loss: 0.1401 | Train Acc: 0.9506 | Val Acc: 0.9531
# Epoch 14/50 | Train Loss: 0.1363 | Val Loss: 0.1277 | Train Acc: 0.9536 | Val Acc: 0.9588
# Epoch 15/50 | Train Loss: 0.1299 | Val Loss: 0.1664 | Train Acc: 0.9564 | Val Acc: 0.9386
# Epoch 16/50 | Train Loss: 0.1238 | Val Loss: 0.1327 | Train Acc: 0.9587 | Val Acc: 0.9583
# Epoch 17/50 | Train Loss: 0.1178 | Val Loss: 0.1220 | Train Acc: 0.9606 | Val Acc: 0.9604
# Epoch 18/50 | Train Loss: 0.1135 | Val Loss: 0.1090 | Train Acc: 0.9621 | Val Acc: 0.9663
# Epoch 19/50 | Train Loss: 0.1105 | Val Loss: 0.1074 | Train Acc: 0.9626 | Val Acc: 0.9652
# Epoch 20/50 | Train Loss: 0.1055 | Val Loss: 0.1222 | Train Acc: 0.9642 | Val Acc: 0.9619
# Epoch 21/50 | Train Loss: 0.1015 | Val Loss: 0.1064 | Train Acc: 0.9658 | Val Acc: 0.9645
# Epoch 22/50 | Train Loss: 0.0988 | Val Loss: 0.1171 | Train Acc: 0.9669 | Val Acc: 0.9631
# Epoch 23/50 | Train Loss: 0.0955 | Val Loss: 0.1049 | Train Acc: 0.9685 | Val Acc: 0.9664
# Epoch 24/50 | Train Loss: 0.0908 | Val Loss: 0.0995 | Train Acc: 0.9697 | Val Acc: 0.9700
# Epoch 25/50 | Train Loss: 0.0883 | Val Loss: 0.0871 | Train Acc: 0.9707 | Val Acc: 0.9729
# Epoch 26/50 | Train Loss: 0.0854 | Val Loss: 0.0995 | Train Acc: 0.9721 | Val Acc: 0.9697
# Epoch 27/50 | Train Loss: 0.0844 | Val Loss: 0.0892 | Train Acc: 0.9724 | Val Acc: 0.9722
# Epoch 28/50 | Train Loss: 0.0810 | Val Loss: 0.0878 | Train Acc: 0.9734 | Val Acc: 0.9729
# Epoch 29/50 | Train Loss: 0.0799 | Val Loss: 0.1067 | Train Acc: 0.9738 | Val Acc: 0.9692
# Epoch 30/50 | Train Loss: 0.0781 | Val Loss: 0.0958 | Train Acc: 0.9743 | Val Acc: 0.9697
# Epoch 31/50 | Train Loss: 0.0766 | Val Loss: 0.0788 | Train Acc: 0.9750 | Val Acc: 0.9760
# Epoch 32/50 | Train Loss: 0.0739 | Val Loss: 0.0931 | Train Acc: 0.9758 | Val Acc: 0.9708
# Epoch 33/50 | Train Loss: 0.0719 | Val Loss: 0.0992 | Train Acc: 0.9767 | Val Acc: 0.9703
# Epoch 34/50 | Train Loss: 0.0702 | Val Loss: 0.0985 | Train Acc: 0.9767 | Val Acc: 0.9715
# Epoch 35/50 | Train Loss: 0.0686 | Val Loss: 0.0814 | Train Acc: 0.9773 | Val Acc: 0.9761
# Epoch 36/50 | Train Loss: 0.0678 | Val Loss: 0.0817 | Train Acc: 0.9779 | Val Acc: 0.9762
# Epoch 37/50 | Train Loss: 0.0658 | Val Loss: 0.0689 | Train Acc: 0.9787 | Val Acc: 0.9792
# Epoch 38/50 | Train Loss: 0.0654 | Val Loss: 0.0700 | Train Acc: 0.9789 | Val Acc: 0.9789
# Epoch 39/50 | Train Loss: 0.0639 | Val Loss: 0.0880 | Train Acc: 0.9793 | Val Acc: 0.9699
# Epoch 40/50 | Train Loss: 0.0623 | Val Loss: 0.0708 | Train Acc: 0.9796 | Val Acc: 0.9801
# Epoch 41/50 | Train Loss: 0.0611 | Val Loss: 0.0780 | Train Acc: 0.9804 | Val Acc: 0.9775
# Epoch 42/50 | Train Loss: 0.0606 | Val Loss: 0.0726 | Train Acc: 0.9801 | Val Acc: 0.9785
# Epoch 43/50 | Train Loss: 0.0591 | Val Loss: 0.0662 | Train Acc: 0.9807 | Val Acc: 0.9804
# Epoch 44/50 | Train Loss: 0.0587 | Val Loss: 0.0660 | Train Acc: 0.9810 | Val Acc: 0.9818
# Epoch 45/50 | Train Loss: 0.0573 | Val Loss: 0.0721 | Train Acc: 0.9813 | Val Acc: 0.9796
# Epoch 46/50 | Train Loss: 0.0562 | Val Loss: 0.0697 | Train Acc: 0.9818 | Val Acc: 0.9805
# Epoch 47/50 | Train Loss: 0.0559 | Val Loss: 0.0735 | Train Acc: 0.9819 | Val Acc: 0.9758
# Epoch 48/50 | Train Loss: 0.0554 | Val Loss: 0.0842 | Train Acc: 0.9821 | Val Acc: 0.9738
# Epoch 49/50 | Train Loss: 0.0544 | Val Loss: 0.0645 | Train Acc: 0.9827 | Val Acc: 0.9805
# Epoch 50/50 | Train Loss: 0.0529 | Val Loss: 0.0612 | Train Acc: 0.9832 | Val Acc: 0.9827

# %%
# ✅ Save model + history
save_dir = "C:/Users/arfao/Desktop/stage_2025/cnn_results"
os.makedirs(save_dir, exist_ok=True)
torch.save(model.state_dict(), os.path.join(save_dir, 'ecg_cnn_model.pth'))
np.save(os.path.join(save_dir, 'ecg_cnn_history.npy'), history)

# %%
# ✅ Plots
plt.figure(figsize=(10,5))
plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Val Loss')
plt.title("Loss over epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history['train_acc'], label='Train Accuracy')
plt.plot(history['val_acc'], label='Val Accuracy')
plt.title("Accuracy over epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# ✅ Evaluation
model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        outputs = model(X_batch)
        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y_batch.cpu().numpy())

print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names))
# Out:
# Classification Report:
#                                precision    recall  f1-score   support
#
#                   Fusion beat       1.00      0.97      0.98    156908
#                   Normal beat       0.55      0.97      0.70       893
# Supraventricular ectopic beat       0.05      0.70      0.09       219
#      Ventricular ectopic beat       0.27      0.92      0.42       493
#
#                      accuracy                           0.97    158513
#                     macro avg       0.47      0.89      0.55    158513
#                  weighted avg       0.99      0.97      0.98    158513

# %%
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
f1_per_class = f1_score(all_labels, all_preds, average=None)
plt.figure(figsize=(8,5))
plt.bar(class_names, f1_per_class)
plt.title("F1 Score per Class")
plt.xlabel("Class")
plt.ylabel("F1 Score")
plt.ylim(0,1)
plt.show()

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
import matplotlib.pyplot as plt
import os

# ✅ Load segmented data
X = np.load("C:/Users/arfao/Desktop/stage_2025/processed_multiclass_filtered500/X_segments.npy")
y = np.load("C:/Users/arfao/Desktop/stage_2025/processed_multiclass_filtered500/y_labels.npy")
print(f"Original class distribution: {Counter(y)}")

# ✅ Plot original class samples
label_name_map = {0: "Fusion beat", 1: "Normal beat", 2: "Supraventricular ectopic beat", 5: "Ventricular ectopic beat"}
unique_classes = np.unique(y)
plt.figure(figsize=(12, 8))
for i, class_label in enumerate(unique_classes):
    idx = (y == class_label).nonzero()[0][0]
    plt.subplot(len(unique_classes), 1, i + 1)
    plt.plot(X[idx], linewidth=1)
    plt.title(f"Example signal of class {class_label}: {label_name_map.get(class_label, 'Unknown')}")
    plt.xlabel("Time step")
    plt.ylabel("Amplitude")
    plt.tight_layout()
plt.show()

# ✅ Flatten + scale
X_flat = X.reshape((X.shape[0], -1))
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat)

# ✅ Apply augmentation
target_count = 70000
minority_classes = [cls for cls in Counter(y) if cls != 0]
smote_strategy = {cls: target_count for cls in minority_classes}

sm = SMOTE(random_state=42, sampling_strategy=smote_strategy)
X_res, y_res = sm.fit_resample(X_scaled, y)

rus = RandomUnderSampler(
    sampling_strategy={0: target_count, **{cls: target_count for cls in np.unique(y_res) if cls != 0}},
    random_state=42
)
X_bal, y_bal = rus.fit_resample(X_res, y_res)
print(f"Balanced dataset: {Counter(y_bal)}")

# ✅ Split after augmentation
X_train, X_test, y_train, y_test = train_test_split(X_bal, y_bal, test_size=0.2, stratify=y_bal, random_state=42)

# ✅ Remap labels
label_map = {0: 0, 1: 1, 2: 2, 5: 3}
class_names = ["Fusion beat", "Normal beat", "Supraventricular ectopic beat", "Ventricular ectopic beat"]

y_train = np.array([label_map[label] for label in y_train])
y_test = np.array([label_map[label] for label in y_test])

# ✅ Reshape for CNN
time_steps = X.shape[1]
X_train_cnn = X_train.reshape((-1, 1, time_steps)).astype(np.float32)
X_test_cnn = X_test.reshape((-1, 1, time_steps)).astype(np.float32)

# ✅ Tensors + datasets
X_train_tensor = torch.tensor(X_train_cnn)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test_cnn)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

train_ds_full = TensorDataset(X_train_tensor, y_train_tensor)
test_ds = TensorDataset(X_test_tensor, y_test_tensor)

val_size = int(0.2 * len(train_ds_full))
train_size = len(train_ds_full) - val_size
train_ds, val_ds = random_split(train_ds_full, [train_size, val_size])

train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=64)
test_loader = DataLoader(test_ds, batch_size=64)

# ✅ Model
class ECG_CNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv1d(1, 16, kernel_size=7, padding=3)
        self.pool1 = nn.MaxPool1d(2)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=5, padding=2)
        self.pool2 = nn.MaxPool1d(2)
        self.conv3 = nn.Conv1d(32, 64, kernel_size=3, padding=1)
        self.pool3 = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(64, num_classes)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = self.pool1(x)
        x = torch.relu(self.conv2(x))
        x = self.pool2(x)
        x = torch.relu(self.conv3(x))
        x = self.pool3(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

model = ECG_CNN(len(class_names))
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# ✅ Training loop with plots
num_epochs = 50
history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}

for epoch in range(num_epochs):
    model.train()
    train_loss, correct, total = 0, 0, 0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == y_batch).sum().item()
        total += y_batch.size(0)
    history['train_loss'].append(train_loss / len(train_loader))
    history['train_acc'].append(correct / total)

    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            val_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            val_correct += (preds == y_batch).sum().item()
            val_total += y_batch.size(0)
    history['val_loss'].append(val_loss / len(val_loader))
    history['val_acc'].append(val_correct / val_total)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {history['train_loss'][-1]:.4f} | Val Loss: {history['val_loss'][-1]:.4f} | Train Acc: {history['train_acc'][-1]:.4f} | Val Acc: {history['val_acc'][-1]:.4f}")

plt.figure(figsize=(10,5))
plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Val Loss')
plt.title("Loss over epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history['train_acc'], label='Train Accuracy')
plt.plot(history['val_acc'], label='Val Accuracy')
plt.title("Accuracy over epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# ✅ Evaluation
model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        outputs = model(X_batch)
        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y_batch.cpu().numpy())

print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names))

cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

f1_per_class = f1_score(all_labels, all_preds, average=None)
plt.figure(figsize=(8,5))
plt.bar(class_names, f1_per_class)
plt.title("F1 Score per Class")
plt.xlabel("Class")
plt.ylabel("F1 Score")
plt.ylim(0,1)
plt.show()
# Out:
# Original class distribution: Counter({0: 784535, 1: 4467, 5: 2466, 2: 1093})
# Balanced dataset: Counter({0: 70000, 1: 70000, 2: 70000, 5: 70000})
# Epoch 1/50 | Train Loss: 0.8262 | Val Loss: 0.7033 | Train Acc: 0.6752 | Val Acc: 0.7354
# Epoch 2/50 | Train Loss: 0.6279 | Val Loss: 0.5698 | Train Acc: 0.7623 | Val Acc: 0.7853
# Epoch 3/50 | Train Loss: 0.4885 | Val Loss: 0.4518 | Train Acc: 0.8194 | Val Acc: 0.8313
# Epoch 4/50 | Train Loss: 0.4039 | Val Loss: 0.3645 | Train Acc: 0.8517 | Val Acc: 0.8653
# Epoch 5/50 | Train Loss: 0.3556 | Val Loss: 0.3529 | Train Acc: 0.8694 | Val Acc: 0.8718
# Epoch 6/50 | Train Loss: 0.3231 | Val Loss: 0.3035 | Train Acc: 0.8813 | Val Acc: 0.8902
# Epoch 7/50 | Train Loss: 0.3008 | Val Loss: 0.3078 | Train Acc: 0.8898 | Val Acc: 0.8849
# Epoch 8/50 | Train Loss: 0.2804 | Val Loss: 0.2639 | Train Acc: 0.8977 | Val Acc: 0.9042
# Epoch 9/50 | Train Loss: 0.2631 | Val Loss: 0.2576 | Train Acc: 0.9051 | Val Acc: 0.9040
# Epoch 10/50 | Train Loss: 0.2504 | Val Loss: 0.2420 | Train Acc: 0.9093 | Val Acc: 0.9113
# Epoch 11/50 | Train Loss: 0.2382 | Val Loss: 0.2350 | Train Acc: 0.9143 | Val Acc: 0.9140
# Epoch 12/50 | Train Loss: 0.2268 | Val Loss: 0.2568 | Train Acc: 0.9196 | Val Acc: 0.9069
# Epoch 13/50 | Train Loss: 0.2167 | Val Loss: 0.2030 | Train Acc: 0.9225 | Val Acc: 0.9262
# Epoch 14/50 | Train Loss: 0.2084 | Val Loss: 0.2170 | Train Acc: 0.9264 | Val Acc: 0.9230
# Epoch 15/50 | Train Loss: 0.2000 | Val Loss: 0.2187 | Train Acc: 0.9296 | Val Acc: 0.9254
# Epoch 16/50 | Train Loss: 0.1920 | Val Loss: 0.1807 | Train Acc: 0.9327 | Val Acc: 0.9377
# Epoch 17/50 | Train Loss: 0.1846 | Val Loss: 0.1913 | Train Acc: 0.9351 | Val Acc: 0.9321
# Epoch 18/50 | Train Loss: 0.1801 | Val Loss: 0.2065 | Train Acc: 0.9367 | Val Acc: 0.9268
# Epoch 19/50 | Train Loss: 0.1733 | Val Loss: 0.1678 | Train Acc: 0.9394 | Val Acc: 0.9438
# Epoch 20/50 | Train Loss: 0.1686 | Val Loss: 0.1713 | Train Acc: 0.9400 | Val Acc: 0.9386
# Epoch 21/50 | Train Loss: 0.1628 | Val Loss: 0.1893 | Train Acc: 0.9429 | Val Acc: 0.9373
# Epoch 22/50 | Train Loss: 0.1579 | Val Loss: 0.1600 | Train Acc: 0.9451 | Val Acc: 0.9435
# Epoch 23/50 | Train Loss: 0.1536 | Val Loss: 0.1573 | Train Acc: 0.9464 | Val Acc: 0.9473
# Epoch 24/50 | Train Loss: 0.1509 | Val Loss: 0.1481 | Train Acc: 0.9472 | Val Acc: 0.9516
# Epoch 25/50 | Train Loss: 0.1474 | Val Loss: 0.1578 | Train Acc: 0.9482 | Val Acc: 0.9466
# Epoch 26/50 | Train Loss: 0.1426 | Val Loss: 0.1479 | Train Acc: 0.9500 | Val Acc: 0.9468
# Epoch 27/50 | Train Loss: 0.1388 | Val Loss: 0.1687 | Train Acc: 0.9524 | Val Acc: 0.9400
# Epoch 28/50 | Train Loss: 0.1382 | Val Loss: 0.1336 | Train Acc: 0.9520 | Val Acc: 0.9538
# Epoch 29/50 | Train Loss: 0.1337 | Val Loss: 0.1379 | Train Acc: 0.9535 | Val Acc: 0.9553
# Epoch 30/50 | Train Loss: 0.1302 | Val Loss: 0.1759 | Train Acc: 0.9551 | Val Acc: 0.9370
# Epoch 31/50 | Train Loss: 0.1272 | Val Loss: 0.1292 | Train Acc: 0.9564 | Val Acc: 0.9571
# Epoch 32/50 | Train Loss: 0.1247 | Val Loss: 0.1439 | Train Acc: 0.9572 | Val Acc: 0.9505
# Epoch 33/50 | Train Loss: 0.1225 | Val Loss: 0.1337 | Train Acc: 0.9576 | Val Acc: 0.9551
# Epoch 34/50 | Train Loss: 0.1189 | Val Loss: 0.1363 | Train Acc: 0.9594 | Val Acc: 0.9563
# Epoch 35/50 | Train Loss: 0.1172 | Val Loss: 0.1250 | Train Acc: 0.9595 | Val Acc: 0.9582
# Epoch 36/50 | Train Loss: 0.1149 | Val Loss: 0.1121 | Train Acc: 0.9604 | Val Acc: 0.9637
# Epoch 37/50 | Train Loss: 0.1123 | Val Loss: 0.1140 | Train Acc: 0.9611 | Val Acc: 0.9633
# Epoch 38/50 | Train Loss: 0.1117 | Val Loss: 0.1109 | Train Acc: 0.9620 | Val Acc: 0.9630
# Epoch 39/50 | Train Loss: 0.1080 | Val Loss: 0.1122 | Train Acc: 0.9631 | Val Acc: 0.9630
# Epoch 40/50 | Train Loss: 0.1064 | Val Loss: 0.1197 | Train Acc: 0.9635 | Val Acc: 0.9625
# Epoch 41/50 | Train Loss: 0.1046 | Val Loss: 0.1040 | Train Acc: 0.9647 | Val Acc: 0.9667
# Epoch 42/50 | Train Loss: 0.1019 | Val Loss: 0.1125 | Train Acc: 0.9652 | Val Acc: 0.9642
# Epoch 43/50 | Train Loss: 0.1016 | Val Loss: 0.1128 | Train Acc: 0.9658 | Val Acc: 0.9625
# Epoch 44/50 | Train Loss: 0.0998 | Val Loss: 0.1274 | Train Acc: 0.9658 | Val Acc: 0.9597
# Epoch 45/50 | Train Loss: 0.0988 | Val Loss: 0.0978 | Train Acc: 0.9665 | Val Acc: 0.9687
# Epoch 46/50 | Train Loss: 0.0954 | Val Loss: 0.1210 | Train Acc: 0.9677 | Val Acc: 0.9616
# Epoch 47/50 | Train Loss: 0.0957 | Val Loss: 0.1006 | Train Acc: 0.9675 | Val Acc: 0.9684
# Epoch 48/50 | Train Loss: 0.0925 | Val Loss: 0.1280 | Train Acc: 0.9692 | Val Acc: 0.9553
# Epoch 49/50 | Train Loss: 0.0920 | Val Loss: 0.1098 | Train Acc: 0.9691 | Val Acc: 0.9646
# Epoch 50/50 | Train Loss: 0.0915 | Val Loss: 0.1201 | Train Acc: 0.9694 | Val Acc: 0.9613
# Classification Report:
#                                precision    recall  f1-score   support
#
#                   Fusion beat       0.94      0.93      0.94     14000
#                   Normal beat       0.99      0.99      0.99     14000
# Supraventricular ectopic beat       0.97      0.92      0.94     14000
#      Ventricular ectopic beat       0.94      1.00      0.97     14000
#
#                      accuracy                           0.96     56000
#                     macro avg       0.96      0.96      0.96     56000
#                  weighted avg       0.96      0.96      0.96     56000
